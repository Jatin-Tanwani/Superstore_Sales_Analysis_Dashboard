# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("superstore.xlsx")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date  Delivery Days  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11              3
# 1       2  CA-2016-152156 2016-11-08 2016-11-11              3
# 2       3  CA-2016-138688 2016-06-12 2016-06-16              4
# 3       4  US-2015-108966 2015-10-11 2015-10-18              7
# 4       5  US-2015-108966 2015-10-11 2015-10-18              7
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# ...

# %%
df.shape
# Out:
# (9994, 25)

# %%
df.tail()
df.describe()
# Out:
#             Row ID                  Order Date                   Ship Date  \
# count  9994.000000                        9994                        9994
# mean   4997.500000  2016-04-30 00:07:12.259355  2016-05-03 23:06:58.571142
# min       1.000000         2014-01-03 00:00:00         2014-01-07 00:00:00
# 25%    2499.250000         2015-05-23 00:00:00         2015-05-27 00:00:00
# 50%    4997.500000         2016-06-26 00:00:00         2016-06-29 00:00:00
# 75%    7495.750000         2017-05-14 00:00:00         2017-05-18 00:00:00
# max    9994.000000         2017-12-30 00:00:00         2018-01-05 00:00:00
# std    2885.163629                         NaN                         NaN
#
#        Delivery Days   Postal Code         Sales     Quantity     Discount  \
# count    9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean        3.958175  55190.379428    229.858001     3.789574     0.156203
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Delivery Days',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Profit Margin', 'Months', 'Years'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   datetime64[us]
#  3   Ship Date      9994 non-null   datetime64[us]
#  4   Delivery Days  9994 non-null   int64
#  5   Ship Mode      9994 non-null   str
#  6   Customer ID    9994 non-null   str
#  7   Customer Name  9994 non-null   str
#  8   Segment        9994 non-null   str
#  9   Country        9994 non-null   str
#  10  City           9994 non-null   str
#  11  State          9994 non-null   str
#  12  Postal Code    9994 non-null   int64
#  13  Region         9994 non-null   str
#  14  Product ID     9994 non-null   str
#  15  Category       9994 non-null   str
#  16  Sub-Category   9994 non-null   str
#  17  Product Name   9994 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Delivery Days    0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# Profit Margin    0
# Months           0
# Years            0
# dtype: int64

# %%
df['Sales'].sum()
# Out:
# np.float64(2297200.8603)

# %%
df['Quantity'].sum()
# Out:
# np.int64(37873)

# %%
df['Profit'].sum()
# Out:
# np.float64(286397.0216999999)

# %%
df['Profit Margin'].sum()
# Out:
# np.float64(1202.417413632119)

# %%
df.groupby('Years')['Sales'].sum().plot()
# Out:
# <Axes: xlabel='Years'>

# %%
df.groupby('Region')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby('Profit')['Years'].sum()
# Out:
# Profit
# -6599.9780    2016
# -3839.9904    2017
# -3701.8928    2014
# -3399.9800    2017
# -2929.4845    2017
#               ...
#  4630.4755    2014
#  4946.3700    2016
#  5039.9856    2017
#  6719.9808    2017
#  8399.9760    2016
# Name: Years, Length: 7545, dtype: int64

# %%
df['order Date']=pd.to_datetime(df['Order Date'])
df['Year']=df['Order Date'].dt.year
df['Month']=df['Order Date'].dt.month

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date  Delivery Days  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11              3
# 1       2  CA-2016-152156 2016-11-08 2016-11-11              3
# 2       3  CA-2016-138688 2016-06-12 2016-06-16              4
# 3       4  US-2015-108966 2015-10-11 2015-10-18              7
# 4       5  US-2015-108966 2015-10-11 2015-10-18              7
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#       Sales Quantity  Discount    Profit Profit Margin    Months Years  \
# ...

# %%
df.groupby('Sub-Category')['Profit'].sum().sort_values()
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Storage        21278.8264
# Chairs         26590.1663
# Binders        30221.7633
# Paper          34053.5693
# Accessories    41936.6357
# Phones         44515.7306
# Copiers        55617.8249
# Name: Profit, dtype: float64

# %%
df['Profit Margin']=(df['Profit']/df['Sales'])*100

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date  Delivery Days  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11              3
# 1       2  CA-2016-152156 2016-11-08 2016-11-11              3
# 2       3  CA-2016-138688 2016-06-12 2016-06-16              4
# 3       4  US-2015-108966 2015-10-11 2015-10-18              7
# 4       5  US-2015-108966 2015-10-11 2015-10-18              7
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#       Sales Quantity  Discount    Profit Profit Margin    Months Years  \
# ...

# %%
df.groupby('Category')['Profit Margin'].mean()
# Out:
# Category
# Furniture           3.878353
# Office Supplies    13.803029
# Technology         15.613805
# Name: Profit Margin, dtype: float64

# %%
df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
year_Sales=df.groupby('Year')['Sales'].sum()
year_Sales
# Out:
# Year
# 2014    484247.4981
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: Sales, dtype: float64

# %%
df.shape
# Out:
# (9994, 28)

# %%
df.to_csv("clean_superstore.csv",index=False)
